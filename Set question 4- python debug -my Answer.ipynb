# %%
#1.Identify and fix the syntax error in the following code:
#ans: Colon was missing in the if statement.

age = 18
if age >= 18:
    print("You are eligible to vote")

# %%
#2.Question:What error will occur in the following code?
# Ans: function call was wrong

def greet():
    print("Hello, World!")

greet()

# %%
#3.Identify the error in this code:
#Ans: age should be consider as string to print the statement. otherwise throw error as - can only concatenate str (not "int") to str

name = "Alice"
age = 25
print("My name is " + name + " and I am " + str(age) + " years old.")

# %%
#4.Question:What will happen when you run this code?
#Ans: Anything divide by 0, will become 0 and throws zerodivisionerror. so we can change the b value

a = 10
b = 1
result = a / b
print(result)

# %%
#5.What error will occur in the following code?
#Ans: Valueerror may arise as string converts into integer. so we can remove the int().

num = "xyz"
print(num)

# %%
#6.Identify the issue in this code:
#Ans: There is no key as city. either we can provide the key present in the dictionary.
data = {"name": "John", "age": 30}
print(data["age"])

# %%
#7.What will happen when you run this code?
#Ans: It will print the num as 1. 
num = 1
while num < 5:
    print(num)

# %%
#8.What is wrong with this code?
#Ans:There is no index 3, it has from 0-2. we have to give the index which is present in the tuple.

fruits = ("apple", "banana", "cherry")
print(fruits[2])

# %%
#9.What will happen when you run this code?
#Ans: It may throw error as we cant able to add anything to string.
text = "hello world"
text.append("!")

# %%
#10.What is wrong with the following code?
#Ans: We can't print this operator directly in the print statement.
import randoms
randoms.randint(1, 10)
print(randoms)
