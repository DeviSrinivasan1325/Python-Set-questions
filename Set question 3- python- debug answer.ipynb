# %%
#1.What is wrong with the following function definition, and how do you fix it?
#def colon is missed,removed + and correctly put coma after "Hello"

def say_hello(name):
    print("Hello",name)
say_hello("Devi")
# Out:
# Hello Devi

# %%
#2.What error will occur in the following code, and how do you fix it?
# typeerror will occur. removed the + and corrected using coma

age = 25
print("I am ",age," years old")
# Out:
# I am  25  years old

# %%
#3.Question: What is the issue with the following code?
#Ans: message variable is under the function, then print the message inside the function.

def greet():
    message = "Hello"
    print(message)
greet()
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?
#Ans: type error of positional or argument will occur as we given single arguement. 

def add(a, b):
    return a + b

print(add(5,6))
# Out:
# 11

# %%
#5.What is wrong with this code?
#Ans: we maintained wrong condition. 
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False
is_even(10)
# Out:
# True

# %%
#6.What happens when you run this code?
#Ans: value error will occur as 10a is not an integer. 
num = "10a"
print(num)
# Out:
# 10a

# %%
#7.What will happen when you run the following code?
#Ans: attribute error will occur due to two operation in same place. separate the operation to get the output.

numbers = [1, 2, 3, 4]
numbers.sort()
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?
# Ans:using append() can modify the list in that place itself without repition. so we should remove reassignment 

numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?
# Ans: unboundlocal error will occur as count is golbal variable, it cannot be in loop without globization.

count = 10

def increment():
    global count
    count+= 1
    print(count)

increment()
# Out:
# 11

# %%
#10.What error will occur in the following code?
#ans: index error will occur as it out of index range.
text = "Python"
if len(text)>10:
    print(text[10])
else:
    print("Index out of range")
# Out:
# Index out of range
